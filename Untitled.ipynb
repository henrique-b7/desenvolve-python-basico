# %%
print("Meu primeiro código")
# Out:
# Meu primeiro código

# %%
x = 10

y = 5

print(x+1)

print(y-2)

print(y*x)

print(x/y)
# Out:
# 11
# 3
# 50
# 2.0

# %%
print("Ola)
# Out:
#   Cell In[3], line 1
#     print("Ola)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)
